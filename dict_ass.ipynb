# %% [markdown]
# # dictionary data structure

# %% [markdown]
# ## create Dictionary

# %%
mydict = dict()

# %%
mydict
# Out:
# {}

# %%
mydictv ={}
mydictv
# Out:
# {}

# %%
mydict = {1:'one' , 2:'two' , 3:'three'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict1 = dict({1:'one' , 2:'two' , 3:'three'}) # Create dictionary using dict()
mydict1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict2 = {'A':'one' , 'B':'two' , 'C':'three'}
mydict2
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict3 = {1:'one' , 'A':'two' , 3:'three'}
mydict3
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
mydict2.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
mydict.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict2.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'three')])

# %%
mydict3.items()
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict4 = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria']}
mydict4
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria']}

# %%
mydict5 = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria'], 'B':('Bat' , 'cat','hat')}
mydict5
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['asif', 'john', 'Maria'],
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a' , 'b' , 'c' , 'd'}
mydict6 = dict.fromkeys(keys)
mydict6
# Out:
# {'a': None, 'b': None, 'd': None, 'c': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = 10
mydict6 = dict.fromkeys(keys , value)
mydict6
# Out:
# {'a': 10, 'b': 10, 'd': 10, 'c': 10}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = 10,20,30
mydict7 = dict.fromkeys(keys , value)
mydict7
# Out:
# {'a': (10, 20, 30), 'b': (10, 20, 30), 'd': (10, 20, 30), 'c': (10, 20, 30)}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = [10,20,30]
mydict7 = dict.fromkeys(keys , value)
mydict7
# Out:
# {'a': [10, 20, 30], 'b': [10, 20, 30], 'd': [10, 20, 30], 'c': [10, 20, 30]}

# %%
value.append(40)
mydict7
# Out:
# {'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40]}

# %% [markdown]
# # Accessing items

# %%
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict[1]
# Out:
# 'one'

# %%
mydict.get(1)
# Out:
# 'one'

# %%
mydict8 = {'Name':'Asif' , 'ID': 74123 , 'DOB': 1991 , 'job' :'Analyst'}
mydict8
# Out:
# {'Name': 'Asif', 'ID': 74123, 'DOB': 1991, 'job': 'Analyst'}

# %%
mydict8['Name']
# Out:
# 'Asif'

# %%
mydict8.get('job')
# Out:
# 'Analyst'

# %% [markdown]
# # Add ,remove and change items

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1['DOB'] = 1992
mydict1['Address'] = 'Delhi'
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst'
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1992,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job')
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
mydict1.popitem()
# Out:
# ('Address', 'Delhi')

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1992}

# %%
del[mydict1['ID']]
mydict1
# Out:
# {'Name': 'Asif', 'DOB': 1992}

# %%
mydict1.clear()
mydict1
# Out:
# {}

# %%
del mydict1
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 del mydict1
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# # copy Dictionary

# %%
mydict = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'}
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1 = mydict

# %%
id(mydict),id(mydict1)
# Out:
# (2171100143936, 2171100143936)

# %%
mydict2 = mydict.copy()

# %%
id(mydict2)
# Out:
# 2171100128064

# %%
mydict['Address'] = 'Mumbai'

# %%
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict2
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# # loop through Dictionary

# %%
mydict2
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
for i in mydict2:
    print(i,':',mydict2[i])  # key value pair
# Out:
# Name : Asif
# ID : 12345
# DOB : 1991
# Address : Hilsinki

# %%
for i in mydict2:
    print(mydict[i])
# Out:
# Asif
# 12345
# 1991
# Mumbai

# %% [markdown]
# # Dictionary Membership

# %%
mydict2
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
'Name' in mydict2
# Out:
# True

# %%
'asif' in mydict2 # works on key
# Out:
# False

# %%
'Asif' in mydict2
# Out:
# False

# %%
'ID' in mydict2
# Out:
# True

# %% [markdown]
# # All/ Any

# %%
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
all(mydict1)
# Out:
# True

# %%
any(mydict1)
# Out:
# True
