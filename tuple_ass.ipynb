# %% [markdown]
# ## tuple dt:2/03

# %% [markdown]
# # tuple creation

# %%
tup1 =()

# %%
tup2 = (10,30,60)
tup2
# Out:
# (10, 30, 60)

# %%
tup3 = (10.77,30.44,60.89)
tup3
# Out:
# (10.77, 30.44, 60.89)

# %%
tup4 = ('one','two','three')
tup4
# Out:
# ('one', 'two', 'three')

# %%
tup5 =('asif',25,34.44,(50,60),(78,95,45))
tup5
# Out:
# ('asif', 25, 34.44, (50, 60), (78, 95, 45))

# %%
tup6 = (100,'asif',10.56)

# %%
tup7 = ('asif',25,[50,100],[65,45],{'john','dev'},(40,50,60))

# %%
len(tup7)
# Out:
# 6

# %% [markdown]
# ## tuple indexing

# %%
tup2[0]
# Out:
# 10

# %%
tup4[0]
# Out:
# 'one'

# %%
tup4[0][0]
# Out:
# 'o'

# %%
tup4[-1]
# Out:
# 'three'

# %%
tup5[-2]
# Out:
# (50, 60)

# %% [markdown]
# ## tuple slicing

# %%
mytup = ('one','two','three','four','five','six','seven','eight','nine')

# %%
mytup[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytup[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytup[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytup[:2]
# Out:
# ('one', 'two')

# %%
mytup[-3:]
# Out:
# ('seven', 'eight', 'nine')

# %%
mytup[-2:]
# Out:
# ('eight', 'nine')

# %%
mytup[-1]
# Out:
# 'nine'

# %%
mytup[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %% [markdown]
# ## remove & change items

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
del mytup[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 del mytup[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytup[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 mytup[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytup # delete entire tuple

# %% [markdown]
# ## loop through tuple

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
for i in mytup : 
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight
# nine

# %%
for i in enumerate(mytup):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')
# (8, 'nine')

# %% [markdown]
# ## tuple membership

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
'one' in mytup
# Out:
# True

# %%
'ten' in mytup
# Out:
# False

# %%
if 'three' in mytup:
    print('3 is there')
else:
    print('3 is not there')
# Out:
# 3 is there

# %%
if 'ten' in mytup:
    print('10 is there')
else:
    print('10 is not there')
# Out:
# 10 is not there

# %% [markdown]
# ## index position

# %%
mytup
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine')

# %%
mytup.index('one')
# Out:
# 0

# %%
mytup.index('five')
# Out:
# 4

# %%
mytup.index('seven')
# Out:
# 6

# %%
tup2
# Out:
# (10, 30, 60)

# %% [markdown]
# ## sorting

# %%
mytup2 = (43,67,99,12,6,90,67)

# %%
sorted(mytup2)
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytup2,reverse=True)
# Out:
# [99, 90, 67, 67, 43, 12, 6]
