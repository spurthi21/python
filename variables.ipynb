# %% [markdown]
# # 3.1.1 Numbers

# %%
2+2
# Out:
# 4

# %%
50-5*6
# Out:
# 20

# %%
(50-5*6)/4
# Out:
# 5.0

# %%
8/5
# Out:
# 1.6

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
5*3+2
# Out:
# 17

# %%
5**3
# Out:
# 125

# %%
2**7
# Out:
# 128

# %%
width=20
height=5*9
width*height
# Out:
# 900

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
4*3.75-1
# Out:
# 14.0

# %%
tax=12.5/100
price=100.50
price*tax
# Out:
# 12.5625

# %%
price + _
# Out:
# 113.0625

# %%
round(_,2)
# Out:
# 113.06

# %% [markdown]
# # 3.1.2 Text

# %%
'spam eggs'
# Out:
# 'spam eggs'

# %%
"paris rabbit got your back:)!"
# Out:
# 'paris rabbit got your back:)!'

# %%
'1956'
# Out:
# '1956'

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
"does't"
# Out:
# "does't"

# %%
'"yes ,"they said'
# Out:
# '"yes ,"they said'

# %%
"\"yes,\"they said"
# Out:
# '"yes,"they said'

# %%
s='first line.\nsecond line.'

# %%
s
# Out:
# 'first line.\n second line.'

# %%
print(s)
# Out:
# first line.
# second line.

# %%
print('C:\some\name')
# Out:
# C:\some
# ame
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\halvi\AppData\Local\Temp\ipykernel_17964\3441249919.py:1: SyntaxWarning: invalid escape sequence '\s'
#   print('C:\some\name')

# %%
print(r'C:\some\name')
# Out:
# C:\some\name

# %%
3*'un'+'ium'
# Out:
# 'unununium'

# %%
'py' 'thon'
# Out:
# 'python'

# %%
text=('put several strings')

# %%
text
# Out:
# 'put several strings'

# %%
word='python'

# %%
word[0]
# Out:
# 'p'

# %%
word[4]
# Out:
# 'o'

# %%
word[-1]
# Out:
# 'n'

# %%
word[-5]
# Out:
# 'y'

# %%
word[0:3]
# Out:
# 'pyt'

# %%
word[2:3]
# Out:
# 't'

# %%
word[:3]
# Out:
# 'pyt'

# %%
word[4:]
# Out:
# 'on'

# %%
word[-2:]
# Out:
# 'on'

# %%
word[:2]+word[2:]
# Out:
# 'python'

# %%
word[:4]+word[4:]
# Out:
# 'python'

# %%
word[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 word[42]
#
# IndexError: string index out of range

# %%
word[0]='J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 word[0]='J'
#
# TypeError: 'str' object does not support item assignment

# %%
word[2:]='py'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 word[2:]='py'
#
# TypeError: 'str' object does not support item assignment

# %%
'J'+word[1:]
# Out:
# 'Jython'

# %%
s = 'hello how are all '
len(s)
# Out:
# 18
