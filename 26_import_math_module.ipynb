# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
pi = 4.17
pi
# Out:
# 4.17

# %%
math.floor(3.23)
# Out:
# 3

# %%
math.ceil(3.23)
# Out:
# 4

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
m.pow(4,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 m.pow(4,2)
#
# NameError: name 'm' is not defined

# %% [markdown]
# # here when you define then only you can use

# %%
# if you

# %%
import math as m

# %%
m.pow(4,2)
# Out:
# 16.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math as m
print(m.pow(3,2))
print(m.floor(3.45))
print(m.ceil(3.45))
# Out:
# 9.0
# 3
# 4

# %% [markdown]
# # in short we can write

# %%
from math import sqrt,pow ,floor ,ceil
print(pow(3,2))
print(floor(3.46))
print(sqrt(10))
# Out:
# 9.0
# 3
# 3.1622776601683795

# %% [markdown]
# ## input function

# %%
x = input()
x
# Out:
#  hello everyone
# 'hello everyone'

# %%
x = input()
y = input()
x
y
# Out:
#  5
#  6
# '6'

# %% [markdown]
# # here it consider the integer to string so it concatinate it

# %%
x = input()
y = input()
z = x + y 
print(z)
# Out:
#  5
#  6
# 56

# %%
type(x)
# Out:
# str

# %% [markdown]
# # so for addtion we have to mention int fn

# %%
x = int(input())
y = int(input())
z = x + y 
print('total=',z)
# Out:
#  5
#  9
# total= 14

# %%
x = int(input('enter value 1 -'))
y = int(input('enter value 2 -'))
z = x + y 
print('total =',z)
# Out:
# enter value 1 - 5
# enter value 2 - 6
# total = 11

# %% [markdown]
# # string input

# %%
st = input('enter string ')
print(st)
# Out:
# enter string  shduhfi
# shduhfi

# %%
x1 = input('user_name') 
y1 = input('password') 
z1 = x1 + y1
print(z1)
# Out:
# user_name hello
# password 12334
# hello 12334

# %%
st = input('enter string ')
print(st)
# Out:
# enter string  spurthi
# spurthi

# %%
print(st[2])
# Out:
# u

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string spurthi
# s

# %%
st = input('enter a string')[3:]
print(st)
# Out:
# enter a string spurthi
# rthi

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string 12+10-2
# 12+10-2

# %%
st = int(input('enter a string'))
print(st)
# Out:
# enter a string 12+10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 st = int(input('enter a string'))
#       2 print(st)
#
# ValueError: invalid literal for int() with base 10: '12+10'

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 12+10-2
# 20
