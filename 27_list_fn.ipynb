# %% [markdown]
# ## list DS

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l.append(20,30)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [ ]
l1
# Out:
# []

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
li == l
# Out:
# True

# %%
print(id(l))
print(id(l1))
# Out:
# 1958803535936
# 1958811923456

# %%
l2 = []

# %%
l2.append(2)
l2.append(2.3)
l2.append(True)
l2.append(21+2j)
l2.append('nit')
l2.append([31,41,51])

# %%
l2
# Out:
# [2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
l1.count(20)
# Out:
# 1

# %%
l1.extend(l2)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]
# [2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
l1.index(2.3)
# Out:
# 7

# %%
l1.index(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l1.index(200)
#
# ValueError: 200 is not in list

# %%
l2.index([31,41,51])
# Out:
# 5

# %%
l2
# Out:
# [2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
for i in l2:
    print(i)
# Out:
# 2
# 2.3
# True
# (21+2j)
# nit
# [31, 41, 51]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
l1.insert(1,15)

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (21+2j), 'nit', [31, 41, 51]]

# %%
sal =[5000,5000,10000]
sal
# Out:
# [5000, 5000, 10000]

# %%
sal[2]
# Out:
# 10000

# %%
l1.pop()
# Out:
# [31, 41, 51]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 2, 2.3, True, (21+2j), 'nit']

# %%
l1.pop(3)
# Out:
# 30

# %%
l1.remove(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 l1.remove(200)
#
# ValueError: list.remove(x): x not in list

# %%
l1.remove(2.3)

# %%
l1
# Out:
# [10, 15, 20, 40, 50, 10, 2, True, (21+2j), 'nit']
